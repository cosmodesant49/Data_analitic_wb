# %%
import os

folder_path = '/content/drive/My Drive/'

files = os.listdir(folder_path)

for file in files:
    print(f'{folder_path}{file}')
# Out:
# /content/drive/My Drive/Classroom
# /content/drive/My Drive/Production Internship Report SAMPLE: Baiel Avtandilov CSC-22.gdoc
# /content/drive/My Drive/csc-22 BAIEL ACTANDILOV.blend
# /content/drive/My Drive/untitled.png
# /content/drive/My Drive/baiel dise.blend
# /content/drive/My Drive/baiel dise 2.blend
# /content/drive/My Drive/Demo Internship Video scenario Baiel avtandilov.gdoc
# /content/drive/My Drive/DALL·E 2024-10-09 10.54.35 - A young Asian Kyrgyz man, around 18 years old, working in an office setting. He is sitting at a desk, wearing a smart-casual outfit, with a 3D printer.webp
# /content/drive/My Drive/dise baiel avtandilov.png
# /content/drive/My Drive/dise baiel avtandilov1.png
# /content/drive/My Drive/baiel dise 3.blend
# /content/drive/My Drive/cubik rubik baiel.png
# /content/drive/My Drive/baiel cubik.blend1
# /content/drive/My Drive/baiel cibuk.blend
# /content/drive/My Drive/baiel mid.png
# /content/drive/My Drive/baiel mid.blend
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

file_path = '/content/drive/My Drive/amazon database Akram.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['рейтинг'], y=df['общее количество рейтингов'])
# Out:
# <Axes: xlabel='рейтинг', ylabel='общее количество рейтингов'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

file_path = '/content/drive/My Drive/amazon database Akram.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['рейтинг'], y=df['Цена'])
# Out:
# <Axes: xlabel='рейтинг', ylabel='Цена'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

file_path = '/content/drive/My Drive/amazon database Akram.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['рейтинг'], y=df['Продажи за месяц'])
# Out:
# <Axes: xlabel='рейтинг', ylabel='Продажи за месяц'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

file_path = '/content/drive/My Drive/amazon database Akram.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

plt.figure(figsize=(10, 6))
x = df[['Цена','Продажи за месяц','общее количество рейтингов','рейтинг']]
x.corr()
# Out:
#                                 Цена  Продажи за месяц  \
# Цена                        1.000000          0.136561
# Продажи за месяц            0.136561          1.000000
# общее количество рейтингов  0.030981          0.168165
# рейтинг                    -0.014562         -0.068877
#
#                             общее количество рейтингов   рейтинг
# Цена                                          0.030981 -0.014562
# Продажи за месяц                              0.168165 -0.068877
# общее количество рейтингов                    1.000000 -0.007656
# рейтинг                                      -0.007656  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

file_path = '/content/drive/My Drive/amazon database Akram.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

plt.figure(figsize=(16, 6))
sns.pointplot(x=df['Продажи за месяц'], y=df['Цена'])
# Out:
# <Axes: xlabel='Продажи за месяц', ylabel='Цена'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

file_path = '/content/drive/My Drive/amazon database Akram.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['общее количество рейтингов'], y=df['Цена'])
# Out:
# <Axes: xlabel='общее количество рейтингов', ylabel='Цена'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

file_path = '/content/drive/My Drive/amazon database Akram.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

plt.figure(figsize=(16, 6))
sns.pointplot(x=df['Продажи за месяц'], y=df['общее количество рейтингов'])
# Out:
# <Axes: xlabel='Продажи за месяц', ylabel='общее количество рейтингов'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

file_path = '/content/drive/My Drive/amazon database Akram.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

x = df[['Цена','Продажи за месяц','общее количество рейтингов','рейтинг']]
sns.heatmap(x.corr(), xticklabels=x.corr().columns, yticklabels=x.corr().columns, cmap='RdYlGn', center=0, annot=True)
# Out:
# <Axes: >
